# %%
import tensorflow as tf
print("Kullanılabilir GPU Sayısı: ", len(tf.config.experimental.list_physical_devices('GPU')))
from tensorflow.keras import layers, models, applications
import matplotlib.pyplot as plt
import numpy as np
import os
import time
# Out:
# Kullanılabilir GPU Sayısı:  1

# %%
TRAIN_DIR = "C:\\Users\\ofaru\\Desktop\\GitHub\\Gastroenterology-CNN-Comparison\\data\\prepared-data-grayscale\\train"  
VAL_DIR = "C:\\Users\\ofaru\\Desktop\\GitHub\\Gastroenterology-CNN-Comparison\\data\\prepared-data-grayscale\\val"
IMG_SIZE = (224, 224)
BATCH_SIZE = 64
NUM_CLASSES = 8 # Kvasir-v2 için 8 sınıf var
EPOCHS = 50 # Denemeler için sonrasında artırılabilir
MODEL_SAVE_PATH = "C:\\Users\\ofaru\\Desktop\\GitHub\\Gastroenterology-CNN-Comparison\\models\\" # Modellerin kaydedileceği yer

# Klasörün var olduğundan emin ol
os.makedirs(MODEL_SAVE_PATH, exist_ok=True)

# %%
# 'categorical' kullanıyoruz çünkü 8 sınıfımız var
train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

validation_dataset = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

class_names = train_dataset.class_names
print("Sınıflar:", class_names)

# Performans için veri setlerini önbelleğe al
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 6400 files belonging to 8 classes.
# Found 800 files belonging to 8 classes.
# Sınıflar: ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']

# %%
def get_base_model():
    return applications.MobileNetV3Large(input_shape=(*IMG_SIZE, 3), include_top=False, weights='imagenet')

def get_preprocessing_pipeline():
    return models.Sequential([
        layers.Input(shape=(*IMG_SIZE, 3)) 
    ], name="mobilenet_grayscale_pipeline")

experiment_name = "mobilenetv3_large_grayscale"

# %%
def create_model(base_model_func, preprocessing_pipeline_func, num_classes):
    # Transfer Learning için temel modeli al ve dondur
    base_model = base_model_func()
    base_model.trainable = False
    
    # Ön işleme hattını al
    preprocessing_pipeline = preprocessing_pipeline_func()
    
    # Modeli birleştir
    inputs = layers.Input(shape=(*IMG_SIZE, 3), name="input_layer")
    x = preprocessing_pipeline(inputs)
    x = base_model(x, training=False) # 'training=False' önemlidir
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    
    model = models.Model(inputs, outputs)
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

print(f"Deney Başlatılıyor: {experiment_name}")
model = create_model(get_base_model, get_preprocessing_pipeline, NUM_CLASSES)
model.summary()
# Out:
# Deney Başlatılıyor: mobilenetv3_large_grayscale
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  mobilenet_grayscale_pipelin  (None, 224, 224, 3)      0
#  e (Sequential)
#
#  MobilenetV3large (Functiona  (None, 7, 7, 960)        2996352
#  l)
#
#  global_average_pooling2d_1   (None, 960)              0
#  (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 960)               0
#
#  dense_1 (Dense)             (None, 8)                 7688
#
# =================================================================
# Total params: 3,004,040
# Trainable params: 7,688
# Non-trainable params: 2,996,352
# _________________________________________________________________

# %%
start_time = time.time()
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=validation_dataset
)
end_time = time.time()
print(f"Eğitim Süresi: {end_time - start_time:.2f} saniye")
# Out:
# Epoch 1/50
# 100/100 [==============================] - 8s 61ms/step - loss: 1.3670 - accuracy: 0.4966 - val_loss: 0.6333 - val_accuracy: 0.7750
# Epoch 2/50
# 100/100 [==============================] - 6s 55ms/step - loss: 0.7034 - accuracy: 0.7255 - val_loss: 0.5102 - val_accuracy: 0.8025
# Epoch 3/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.5953 - accuracy: 0.7713 - val_loss: 0.4653 - val_accuracy: 0.8163
# Epoch 4/50
# 100/100 [==============================] - 5s 52ms/step - loss: 0.5387 - accuracy: 0.7919 - val_loss: 0.4251 - val_accuracy: 0.8338
# Epoch 5/50
# 100/100 [==============================] - 5s 52ms/step - loss: 0.5080 - accuracy: 0.8047 - val_loss: 0.4128 - val_accuracy: 0.8363
# Epoch 6/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.4754 - accuracy: 0.8178 - val_loss: 0.4109 - val_accuracy: 0.8300
# Epoch 7/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.4682 - accuracy: 0.8200 - val_loss: 0.3939 - val_accuracy: 0.8325
# Epoch 8/50
# 100/100 [==============================] - 6s 55ms/step - loss: 0.4448 - accuracy: 0.8331 - val_loss: 0.3851 - val_accuracy: 0.8400
# Epoch 9/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.4300 - accuracy: 0.8327 - val_loss: 0.3858 - val_accuracy: 0.8375
# Epoch 10/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.4254 - accuracy: 0.8389 - val_loss: 0.3735 - val_accuracy: 0.8388
# Epoch 11/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.4061 - accuracy: 0.8434 - val_loss: 0.3689 - val_accuracy: 0.8425
# Epoch 12/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.4022 - accuracy: 0.8470 - val_loss: 0.3708 - val_accuracy: 0.8388
# Epoch 13/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.4005 - accuracy: 0.8494 - val_loss: 0.3710 - val_accuracy: 0.8400
# Epoch 14/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3918 - accuracy: 0.8481 - val_loss: 0.3664 - val_accuracy: 0.8438
# Epoch 15/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3794 - accuracy: 0.8555 - val_loss: 0.3638 - val_accuracy: 0.8388
# Epoch 16/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3838 - accuracy: 0.8523 - val_loss: 0.3642 - val_accuracy: 0.8413
# Epoch 17/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3759 - accuracy: 0.8570 - val_loss: 0.3550 - val_accuracy: 0.8475
# Epoch 18/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3755 - accuracy: 0.8537 - val_loss: 0.3659 - val_accuracy: 0.8338
# Epoch 19/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3676 - accuracy: 0.8559 - val_loss: 0.3542 - val_accuracy: 0.8425
# Epoch 20/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3546 - accuracy: 0.8631 - val_loss: 0.3534 - val_accuracy: 0.8450
# Epoch 21/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3591 - accuracy: 0.8630 - val_loss: 0.3570 - val_accuracy: 0.8438
# Epoch 22/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3585 - accuracy: 0.8633 - val_loss: 0.3613 - val_accuracy: 0.8413
# Epoch 23/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3598 - accuracy: 0.8617 - val_loss: 0.3543 - val_accuracy: 0.8475
# Epoch 24/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3529 - accuracy: 0.8605 - val_loss: 0.3623 - val_accuracy: 0.8350
# Epoch 25/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3504 - accuracy: 0.8633 - val_loss: 0.3568 - val_accuracy: 0.8375
# Epoch 26/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3515 - accuracy: 0.8631 - val_loss: 0.3547 - val_accuracy: 0.8487
# Epoch 27/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3505 - accuracy: 0.8662 - val_loss: 0.3620 - val_accuracy: 0.8462
# Epoch 28/50
# 100/100 [==============================] - 5s 52ms/step - loss: 0.3449 - accuracy: 0.8655 - val_loss: 0.3653 - val_accuracy: 0.8388
# Epoch 29/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3398 - accuracy: 0.8620 - val_loss: 0.3538 - val_accuracy: 0.8375
# Epoch 30/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3451 - accuracy: 0.8691 - val_loss: 0.3518 - val_accuracy: 0.8438
# Epoch 31/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3376 - accuracy: 0.8644 - val_loss: 0.3578 - val_accuracy: 0.8400
# Epoch 32/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3414 - accuracy: 0.8659 - val_loss: 0.3473 - val_accuracy: 0.8462
# Epoch 33/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3321 - accuracy: 0.8725 - val_loss: 0.3543 - val_accuracy: 0.8450
# Epoch 34/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3386 - accuracy: 0.8650 - val_loss: 0.3579 - val_accuracy: 0.8425
# Epoch 35/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3362 - accuracy: 0.8692 - val_loss: 0.3592 - val_accuracy: 0.8400
# Epoch 36/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3287 - accuracy: 0.8709 - val_loss: 0.3506 - val_accuracy: 0.8537
# Epoch 37/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3331 - accuracy: 0.8716 - val_loss: 0.3599 - val_accuracy: 0.8425
# Epoch 38/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3306 - accuracy: 0.8705 - val_loss: 0.3479 - val_accuracy: 0.8450
# Epoch 39/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3266 - accuracy: 0.8678 - val_loss: 0.3560 - val_accuracy: 0.8462
# Epoch 40/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3254 - accuracy: 0.8706 - val_loss: 0.3545 - val_accuracy: 0.8475
# Epoch 41/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3206 - accuracy: 0.8784 - val_loss: 0.3577 - val_accuracy: 0.8450
# Epoch 42/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3214 - accuracy: 0.8766 - val_loss: 0.3581 - val_accuracy: 0.8462
# Epoch 43/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3190 - accuracy: 0.8741 - val_loss: 0.3450 - val_accuracy: 0.8450
# Epoch 44/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3233 - accuracy: 0.8786 - val_loss: 0.3533 - val_accuracy: 0.8400
# Epoch 45/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3209 - accuracy: 0.8756 - val_loss: 0.3450 - val_accuracy: 0.8525
# Epoch 46/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3245 - accuracy: 0.8734 - val_loss: 0.3503 - val_accuracy: 0.8462
# Epoch 47/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3155 - accuracy: 0.8764 - val_loss: 0.3568 - val_accuracy: 0.8400
# Epoch 48/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3190 - accuracy: 0.8758 - val_loss: 0.3520 - val_accuracy: 0.8438
# Epoch 49/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3118 - accuracy: 0.8756 - val_loss: 0.3618 - val_accuracy: 0.8425
# Epoch 50/50
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3111 - accuracy: 0.8797 - val_loss: 0.3513 - val_accuracy: 0.8450
# Eğitim Süresi: 267.74 saniye

# %%
model_filename = os.path.join(MODEL_SAVE_PATH, f"{experiment_name}.h5")
model.save(model_filename)
print(f"Model başarıyla kaydedildi: {model_filename}")
# Out:
# Model başarıyla kaydedildi: C:\Users\ofaru\Desktop\GitHub\Gastroenterology-CNN-Comparison\models\mobilenetv3_large_grayscale.h5

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Eğitim Doğruluğu')
plt.plot(val_acc, label='Validasyon Doğruluğu')
plt.legend(loc='lower right')
plt.title(f'{experiment_name} - Doğruluk Grafiği')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Eğitim Kaybı')
plt.plot(val_loss, label='Validasyon Kaybı')
plt.legend(loc='upper right')
plt.title(f'{experiment_name} - Kayıp Grafiği')
plt.show()
