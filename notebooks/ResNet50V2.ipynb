# %%
import tensorflow as tf
print("Kullanılabilir GPU Sayısı: ", len(tf.config.experimental.list_physical_devices('GPU')))
from tensorflow.keras import layers, models, applications
import matplotlib.pyplot as plt
import numpy as np
import os
import time
# Out:
# Kullanılabilir GPU Sayısı:  1

# %%
TRAIN_DIR = "C:\\Users\\ofaru\\Desktop\\GitHub\\Gastroenterology-CNN-Comparison\\data\\prepared-data\\train"  
VAL_DIR = "C:\\Users\\ofaru\\Desktop\\GitHub\\Gastroenterology-CNN-Comparison\\data\\prepared-data\\val"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
NUM_CLASSES = 8 # Kvasir-v2 için 8 sınıf var
EPOCHS = 35 # Denemeler için 20, sonrasında artırılabilir
MODEL_SAVE_PATH = "C:\\Users\\ofaru\\Desktop\\GitHub\\Gastroenterology-CNN-Comparison\\models\\" # Modellerin kaydedileceği yer

# Klasörün var olduğundan emin ol
os.makedirs(MODEL_SAVE_PATH, exist_ok=True)

# %%
# 'categorical' kullanıyoruz çünkü 8 sınıfımız var
train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

validation_dataset = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

class_names = train_dataset.class_names
print("Sınıflar:", class_names)

# Performans için veri setlerini önbelleğe al
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 5592 files belonging to 8 classes.
# Found 1600 files belonging to 8 classes.
# Sınıflar: ['dyed-lifted-polyps', 'dyed-resection-margins', 'esophagitis', 'normal-cecum', 'normal-pylorus', 'normal-z-line', 'polyps', 'ulcerative-colitis']

# %%
def get_base_model():
    return applications.ResNet50V2(input_shape=(*IMG_SIZE, 3), include_top=False, weights='imagenet')

def get_preprocessing_pipeline():
    return models.Sequential([
        layers.Input(shape=(*IMG_SIZE, 3)),
        layers.Lambda(lambda x: tf.keras.applications.resnet_v2.preprocess_input(x))
    ], name="resnet_baseline_pipeline")

experiment_name = "resnet50v2_baseline"

# %%
def create_model(base_model_func, preprocessing_pipeline_func, num_classes):
    # Transfer Learning için temel modeli al ve dondur
    base_model = base_model_func()
    base_model.trainable = False
    
    # Ön işleme hattını al
    preprocessing_pipeline = preprocessing_pipeline_func()
    
    # Modeli birleştir
    inputs = layers.Input(shape=(*IMG_SIZE, 3), name="input_layer")
    x = preprocessing_pipeline(inputs)
    x = base_model(x, training=False) # 'training=False' önemlidir
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    
    model = models.Model(inputs, outputs)
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

print(f"Deney Başlatılıyor: {experiment_name}")
model = create_model(get_base_model, get_preprocessing_pipeline, NUM_CLASSES)
model.summary()
# Out:
# Deney Başlatılıyor: resnet50v2_baseline
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  resnet_baseline_pipeline (S  (None, 224, 224, 3)      0
#  equential)
#
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 8)                 16392
#
# =================================================================
# Total params: 23,581,192
# Trainable params: 16,392
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
start_time = time.time()
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=validation_dataset
)
end_time = time.time()
print(f"Eğitim Süresi: {end_time - start_time:.2f} saniye")
# Out:
# Epoch 1/35
# 175/175 [==============================] - 27s 110ms/step - loss: 0.8309 - accuracy: 0.6947 - val_loss: 0.4405 - val_accuracy: 0.8281
# Epoch 2/35
# 175/175 [==============================] - 19s 106ms/step - loss: 0.4347 - accuracy: 0.8267 - val_loss: 0.3898 - val_accuracy: 0.8394
# Epoch 3/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.3686 - accuracy: 0.8555 - val_loss: 0.3637 - val_accuracy: 0.8506
# Epoch 4/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.3283 - accuracy: 0.8689 - val_loss: 0.3524 - val_accuracy: 0.8544
# Epoch 5/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.3042 - accuracy: 0.8791 - val_loss: 0.3372 - val_accuracy: 0.8650
# Epoch 6/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.2871 - accuracy: 0.8863 - val_loss: 0.3438 - val_accuracy: 0.8587
# Epoch 7/35
# 175/175 [==============================] - 19s 107ms/step - loss: 0.2655 - accuracy: 0.8922 - val_loss: 0.3342 - val_accuracy: 0.8656
# Epoch 8/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.2569 - accuracy: 0.8977 - val_loss: 0.3240 - val_accuracy: 0.8687
# Epoch 9/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.2402 - accuracy: 0.9022 - val_loss: 0.3294 - val_accuracy: 0.8675
# Epoch 10/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.2386 - accuracy: 0.9041 - val_loss: 0.3248 - val_accuracy: 0.8687
# Epoch 11/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.2332 - accuracy: 0.9043 - val_loss: 0.3266 - val_accuracy: 0.8669
# Epoch 12/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.2178 - accuracy: 0.9151 - val_loss: 0.3344 - val_accuracy: 0.8700
# Epoch 13/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.2206 - accuracy: 0.9113 - val_loss: 0.3371 - val_accuracy: 0.8675
# Epoch 14/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.2128 - accuracy: 0.9158 - val_loss: 0.3329 - val_accuracy: 0.8681
# Epoch 15/35
# 175/175 [==============================] - 18s 103ms/step - loss: 0.2206 - accuracy: 0.9092 - val_loss: 0.3372 - val_accuracy: 0.8656
# Epoch 16/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.2096 - accuracy: 0.9142 - val_loss: 0.3463 - val_accuracy: 0.8650
# Epoch 17/35
# 175/175 [==============================] - 18s 106ms/step - loss: 0.2057 - accuracy: 0.9179 - val_loss: 0.3381 - val_accuracy: 0.8681
# Epoch 18/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.2054 - accuracy: 0.9177 - val_loss: 0.3412 - val_accuracy: 0.8656
# Epoch 19/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.2002 - accuracy: 0.9199 - val_loss: 0.3375 - val_accuracy: 0.8650
# Epoch 20/35
# 175/175 [==============================] - 18s 106ms/step - loss: 0.2016 - accuracy: 0.9179 - val_loss: 0.3377 - val_accuracy: 0.8781
# Epoch 21/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1930 - accuracy: 0.9190 - val_loss: 0.3391 - val_accuracy: 0.8744
# Epoch 22/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.1898 - accuracy: 0.9235 - val_loss: 0.3486 - val_accuracy: 0.8650
# Epoch 23/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1818 - accuracy: 0.9285 - val_loss: 0.3432 - val_accuracy: 0.8687
# Epoch 24/35
# 175/175 [==============================] - 18s 106ms/step - loss: 0.1775 - accuracy: 0.9292 - val_loss: 0.3344 - val_accuracy: 0.8744
# Epoch 25/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.1822 - accuracy: 0.9267 - val_loss: 0.3465 - val_accuracy: 0.8737
# Epoch 26/35
# 175/175 [==============================] - 18s 106ms/step - loss: 0.1848 - accuracy: 0.9279 - val_loss: 0.3512 - val_accuracy: 0.8644
# Epoch 27/35
# 175/175 [==============================] - 18s 105ms/step - loss: 0.1866 - accuracy: 0.9242 - val_loss: 0.3486 - val_accuracy: 0.8687
# Epoch 28/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1754 - accuracy: 0.9304 - val_loss: 0.3493 - val_accuracy: 0.8669
# Epoch 29/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1809 - accuracy: 0.9270 - val_loss: 0.3634 - val_accuracy: 0.8581
# Epoch 30/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1842 - accuracy: 0.9224 - val_loss: 0.3535 - val_accuracy: 0.8744
# Epoch 31/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1712 - accuracy: 0.9312 - val_loss: 0.3698 - val_accuracy: 0.8656
# Epoch 32/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1626 - accuracy: 0.9310 - val_loss: 0.3546 - val_accuracy: 0.8625
# Epoch 33/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1672 - accuracy: 0.9337 - val_loss: 0.3554 - val_accuracy: 0.8687
# Epoch 34/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1727 - accuracy: 0.9297 - val_loss: 0.3503 - val_accuracy: 0.8675
# Epoch 35/35
# 175/175 [==============================] - 18s 104ms/step - loss: 0.1627 - accuracy: 0.9369 - val_loss: 0.3629 - val_accuracy: 0.8737
# Eğitim Süresi: 649.51 saniye

# %%
model_filename = os.path.join(MODEL_SAVE_PATH, f"{experiment_name}.h5")
model.save(model_filename)
print(f"Model başarıyla kaydedildi: {model_filename}")
# Out:
# Model başarıyla kaydedildi: C:\Users\ofaru\Desktop\GitHub\Gastroenterology-CNN-Comparison\models\resnet50v2_baseline.h5

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Eğitim Doğruluğu')
plt.plot(val_acc, label='Validasyon Doğruluğu')
plt.legend(loc='lower right')
plt.title(f'{experiment_name} - Doğruluk Grafiği')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Eğitim Kaybı')
plt.plot(val_loss, label='Validasyon Kaybı')
plt.legend(loc='upper right')
plt.title(f'{experiment_name} - Kayıp Grafiği')
plt.show()
